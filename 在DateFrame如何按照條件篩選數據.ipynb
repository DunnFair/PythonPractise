# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\e6380\Desktop\PythonPratic\shoes.xlsx')
df
# Out:
#             產品名稱                                               產品描述      價格  \
# 0         380671                                               沒有資料     NaN
# 1         380671                                               沒有資料     NaN
# 2      Brilliant                                               沒有資料  6800.0
# 3      Brilliant                                               沒有資料  6800.0
# 4      Brilliant                                               沒有資料  6800.0
# ..           ...                                                ...     ...
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#      尺寸   庫存  產品數量
# 0    37  1.0   1.0
# ...

# %%
df["價格"].max() #最大值
# Out:
# 69800.0

# %%
df["價格"].min() #最小值
# Out:
# 1980.0

# %%
df["價格"].mean() #平均值
# Out:
# 9051.526479750779

# %%
df.describe() #對應有數據的地方進行一些計算
# Out:
#                  價格          庫存        產品數量
# count    963.000000  983.000000  984.000000
# mean    9051.526480    1.342828    1.430894
# std    13642.125007    0.741185    0.833737
# min     1980.000000    0.000000    0.000000
# 25%     4980.000000    1.000000    1.000000
# 50%     6280.000000    1.000000    1.000000
# 75%     6800.000000    2.000000    1.000000
# max    69800.000000    5.000000    3.000000

# %%
df[df["價格"]>30000] #針對數據 給予條件做篩選
# Out:
#         產品名稱                                               產品描述       價格  \
# 39  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 40  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 41  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 42  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 43  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 44  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 45  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 46  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 47  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 48  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 49  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 50  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# ...

# %%
df[df["價格"] == df["價格"].max()] #可以依照數據找到相對應的值
# Out:
#         產品名稱                                               產品描述       價格  \
# 39  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 40  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 41  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 42  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 43  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 44  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 45  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 46  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 47  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 48  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 49  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 50  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# ...

# %%
df[df["價格"] == df["價格"].max()]["產品名稱"]#可以依照數據找到相對應的值
# Out:
# 39    Dazzling
# 40    Dazzling
# 41    Dazzling
# 42    Dazzling
# 43    Dazzling
# 44    Dazzling
# 45    Dazzling
# 46    Dazzling
# 47    Dazzling
# 48    Dazzling
# 49    Dazzling
# 50    Dazzling
# 51    Dazzling
# 52    Dazzling
# 53    Dazzling
# 54    Dazzling
# 55    Dazzling
# 56    Dazzling
# 57    Dazzling
# 58    Dazzling
# 59    Dazzling
# 60    Dazzling
# 61    Dazzling
# 62    Dazzling
# 63    Dazzling
# 64    Dazzling
# 65    Dazzling
# 66    Dazzling
# 67    Dazzling
# 68    Dazzling
# 69    Dazzling
# 70    Dazzling
# 71    Dazzling
# 72    Dazzling
# 73    Dazzling
# 74    Dazzling
# 75    Dazzling
# 76    Dazzling
# 77    Dazzling
# 78    Dazzling
# 79    Dazzling
# 80    Dazzling
# 81    Dazzling
# 82    Dazzling
# Name: 產品名稱, dtype: object
