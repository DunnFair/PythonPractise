# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\e6380\Desktop\PythonPratic\shoes.xlsx')
df
# Out:
#             產品名稱                                               產品描述      價格  \
# 0         380671                                               沒有資料     NaN
# 1         380671                                               沒有資料     NaN
# 2      Brilliant                                               沒有資料  6800.0
# 3      Brilliant                                               沒有資料  6800.0
# 4      Brilliant                                               沒有資料  6800.0
# ..           ...                                                ...     ...
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#      尺寸   庫存  產品數量
# 0    37  1.0   1.0
# ...

# %%
shoes_info = {
    "產品名稱":["38017"],
    "產品描述":["沒有資料"],
    "價格":["100"],
    "尺寸":["1"],
    "產品數量":["2"]
}
new_df = pd.DataFrame(shoes_info)
new_df
# Out:
#     產品名稱  產品描述   價格 尺寸 產品數量
# 0  38017  沒有資料  100  1    2

# %%
df
# Out:
#             產品名稱                                               產品描述      價格  \
# 0         380671                                               沒有資料     NaN
# 1         380671                                               沒有資料     NaN
# 2      Brilliant                                               沒有資料  6800.0
# 3      Brilliant                                               沒有資料  6800.0
# 4      Brilliant                                               沒有資料  6800.0
# ..           ...                                                ...     ...
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#      尺寸   庫存  產品數量
# 0    37  1.0   1.0
# ...

# %%
df.shape
# Out:
# (997, 6)

# %%
rows,column = df.shape

# %%
rows
# Out:
# 997

# %%
column
# Out:
# 6

# %%
df
# Out:
#             產品名稱                                               產品描述      價格  \
# 0         380671                                               沒有資料     NaN
# 1         380671                                               沒有資料     NaN
# 2      Brilliant                                               沒有資料  6800.0
# 3      Brilliant                                               沒有資料  6800.0
# 4      Brilliant                                               沒有資料  6800.0
# ..           ...                                                ...     ...
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#      尺寸   庫存  產品數量
# 0    37  1.0   1.0
# ...

# %%
df.head(2) #頭兩行
# Out:
#      產品名稱  產品描述  價格  尺寸   庫存  產品數量
# 0  380671  沒有資料 NaN  37  1.0   1.0
# 1  380671  沒有資料 NaN  38  1.0   1.0

# %%
df.tail() #末五行
# Out:
#             產品名稱                                               產品描述      價格  \
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#     尺寸   庫存  產品數量
# 992  4  1.0   1.0
# 993  5  1.0   1.0
# 994  6  1.0   1.0
# 995  7  1.0   1.0
# 996  9  1.0   1.0

# %%
df[50:100] #可以讀取["起始位置","結束位置"]
# Out:
#         產品名稱                                               產品描述       價格  \
# 50  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 51  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 52  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 53  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 54  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 55  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 56  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 57  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 58  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 59  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 60  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# 61  Dazzling  2016代表色湖水綠，蘊藏匠心獨具巧思的工藝精神，百年世家施華洛世奇的完美結晶，由淺至深閃耀...  69800.0
# ...

# %%
df[1:] #重第一數據到最後一筆
# Out:
#             產品名稱                                               產品描述      價格  \
# 1         380671                                               沒有資料     NaN
# 2      Brilliant                                               沒有資料  6800.0
# 3      Brilliant                                               沒有資料  6800.0
# 4      Brilliant                                               沒有資料  6800.0
# 5      Brilliant                                               沒有資料  6800.0
# ..           ...                                                ...     ...
# 992  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 993  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 994  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 995  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
# 996  Little Elsa  光潔如絲的高級鍛料包覆鞋身，佐以五朵精緻花蕊。蕊心點綴著艾莎公主施以魔法晶瑩剔透的耀眼冰晶，...  2680.0
#
#      尺寸   庫存  產品數量
# 1    38  1.0   1.0
# ...

# %%
df.columns #顯示欄位名稱
# Out:
# Index(['產品名稱', '產品描述', '價格', '尺寸', '庫存', '產品數量'], dtype='object')

# %%
df["產品名稱"] #讀取對應下方的內容
# Out:
# 0           380671
# 1           380671
# 2        Brilliant
# 3        Brilliant
# 4        Brilliant
#           ...
# 992    Little Elsa
# 993    Little Elsa
# 994    Little Elsa
# 995    Little Elsa
# 996    Little Elsa
# Name: 產品名稱, Length: 997, dtype: object

# %%
df.產品描述[2:6]  #第二種方式可以讀取相關內容
# Out:
# 2    沒有資料
# 3    沒有資料
# 4    沒有資料
# 5    沒有資料
# Name: 產品描述, dtype: object

# %%
df[["產品名稱","價格"]] #將欄位名稱放入List當中
# Out:
#             產品名稱      價格
# 0         380671     NaN
# 1         380671     NaN
# 2      Brilliant  6800.0
# 3      Brilliant  6800.0
# 4      Brilliant  6800.0
# ..           ...     ...
# 992  Little Elsa  2680.0
# 993  Little Elsa  2680.0
# 994  Little Elsa  2680.0
# 995  Little Elsa  2680.0
# 996  Little Elsa  2680.0
#
# [997 rows x 2 columns]
